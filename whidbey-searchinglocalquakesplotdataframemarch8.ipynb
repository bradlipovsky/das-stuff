# %% [markdown]
# # Earthquake seismology with DAS
#
# #### Todo List:
# 1. Reference earthquakes by Evid rather than dataframe index
# 2. Make a map of all of the detected events
# 3. Try some xcorr

# %%
import h5py
import matplotlib.pyplot as plt
from scipy.signal import butter, filtfilt
import numpy as np
import datetime
import pandas as pd
from dasquakes import sintela_to_datetime, open_sintela_file, local_earthquake_quicklook, data_wrangler, haversine
import obspy
from obspy import UTCDateTime
from obspy.clients.fdsn import Client
from libcomcat.search import search
from libcomcat.dataframes import get_summary_data_frame
import geopy.distance
from obspy.taup import TauPyModel
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /home/velgueta/.conda/envs/python-obspy/share/proj failed

# %% [markdown]
# ### Get a list of events from USGS

# %%
events = search(starttime = datetime.datetime(2022, 3, 17, 0, 0), 
                endtime   = datetime.datetime(2023,1,7,0,0),
                minmagnitude=3.0,
                maxradiuskm=600, 
                latitude=47.60, 
                longitude=-122.33)

print("Returned %s events" % len(events))
# Out:
# Returned 28 events

# %% [markdown]
# ### Choose an event to analyze

# %%
event_df = get_summary_data_frame(events)
event_df = event_df.sort_values(by=['time'],ascending=False)
event_df


#event_df.iloc[0::]
# Out:
#             id                    time                               location  \
# 27  us7000j3g5 2022-12-28 08:07:48.265            off the coast of Washington
# 26  us7000j3f8 2022-12-28 08:06:54.980            267 km SW of Tofino, Canada
# 25  us7000ishe 2022-11-26 03:50:17.526             18 km NW of Tofino, Canada
# 24  us7000iqsk 2022-11-18 15:42:45.032                off the coast of Oregon
# 23  us7000imha 2022-11-04 14:16:58.043                Off the coast of Oregon
# 22  us7000im59 2022-11-03 09:57:33.841                Off the coast of Oregon
# 21  us7000ikhh 2022-10-26 15:18:19.752           169 km W of Langlois, Oregon
# 20  us6000itsl 2022-10-14 21:23:02.037      152 km WNW of Port Orford, Oregon
# 19  uw61886506 2022-10-07 12:52:36.010            16 km ESE of Lacomb, Oregon
# 18  us6000ipd3 2022-09-29 15:09:32.565            off the coast of Washington
# 17  uw61882431 2022-09-22 14:41:56.900         26 km WNW of Forks, Washington
# 16  us7000ia3v 2022-09-22 08:47:50.199             225 km W of Bandon, Oregon
# 15  us7000i88d 2022-09-15 09:21:38.195             151 km W of Bandon, Oregon
# 14  uw61869652 2022-09-08 08:08:25.830         7 km WNW of Lofall, Washington
# 13  us7000i36x 2022-08-28 21:26:11.014           188 km WNW of Bandon, Oregon
# 12  uw61862977 2022-08-13 13:31:22.900      21 km NW of Bickleton, Washington
# 11  us6000iac9 2022-08-12 20:00:04.319            148 km W of Yachats, Oregon
# 10  us6000iabx 2022-08-12 19:14:42.803                off the coast of Oregon
# 9   us6000i90r 2022-08-08 07:38:56.410             201 km W of Tofino, Canada
# 8   uw61860022 2022-08-04 13:22:39.400  6 km SSE of Black Diamond, Washington
# 7   us6000hziu 2022-07-03 10:42:24.962        9 km WNW of Smiths Ferry, Idaho
# 6   uw61836427 2022-05-28 19:07:44.030    55 km NE of Marblemount, Washington
# 5   us6000hn38 2022-05-22 09:58:57.424              2 km WSW of Mullan, Idaho
# 4   uw61832097 2022-05-17 08:07:34.400            6 km ENE of Oso, Washington
# 3   us7000h76t 2022-05-05 03:38:10.239           233 km WSW of Tofino, Canada
# 2   uw61835766 2022-05-01 11:15:56.460     2 km E of Mount Vernon, Washington
# 1   us7000h3bv 2022-04-19 12:43:57.057             191 km W of Bandon, Oregon
# 0   us7000h21e 2022-04-14 01:21:15.822         132 km WNW of Langlois, Oregon
#
#      latitude   longitude   depth  magnitude  alert  \
# 27  47.840200 -128.923300  12.086       3.90   None
# 26  47.804700 -128.908400   9.158       3.80   None
# 25  49.271400 -126.092300  33.380       4.90   None
# 24  43.374100 -126.635600  10.000       4.40   None
# 23  43.401300 -127.099500  10.000       3.40   None
# 22  43.327300 -126.840700  10.000       3.50   None
# 21  43.173500 -126.500500  10.000       3.20   None
# 20  43.070100 -126.307200  10.000       3.30   None
# 19  44.540333 -122.550833  13.170       4.39  green
# 18  47.637400 -128.921800  10.555       3.30   None
# 17  48.046500 -124.715000  37.040       3.49   None
# 16  43.417900 -127.161100  10.000       3.90   None
# 15  43.243600 -126.265300  10.000       4.40   None
# 14  47.842000 -122.751667  23.330       3.71   None
# 13  43.491200 -126.664100  10.000       3.30   None
# 12  46.130333 -120.500000  12.100       3.05   None
# 11  44.483100 -125.947500  10.000       4.00   None
# 10  43.292400 -126.667200  14.823       3.10   None
# 9   48.973600 -128.652200  10.000       4.60   None
# 8   47.258667 -121.971833  21.540       3.06   None
# 7   44.328200 -116.199700   8.750       3.10   None
# 6   48.807833 -120.822500  -0.060       3.16   None
# 5   47.458000 -115.834800   5.000       3.00   None
# 4   48.299667 -121.852000   3.530       3.40   None
# 3   48.556300 -128.954500  10.000       4.10   None
# 2   48.423500 -122.305500  13.540       3.56   None
# 1   43.329500 -126.746800  10.000       3.90   None
# 0   43.173900 -126.045300  10.000       4.20   None
#
#                                                   url   eventtype  \
# 27  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 26  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 25  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 24  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 23  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 22  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 21  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 20  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 19  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 18  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 17  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 16  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 15  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 14  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 13  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 12  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 11  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 10  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 9   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 8   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 7   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 6   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 5   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 4   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 3   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 2   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 1   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 0   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
#
#     significance
# 27           234
# 26           222
# 25           527
# 24           298
# 23           178
# 22           189
# 21           158
# 20           168
# 19           896
# 18           168
# 17           190
# 16           234
# 15           300
# 14           592
# 13           168
# 12           146
# 11           246
# 10           148
# 9            326
# 8            250
# 7            152
# 6            157
# 5            142
# 4            280
# 3            259
# 2            424
# 1            234
# 0            272

# %%
dist_kmarray = []
magnituddarray = []

# %%
for index,this_event in event_df.iterrows():
    
    this_id = this_event['id']
    
    this_event_new = event_df[event_df.id==this_id]
    

    coords_1 = (this_event_new.latitude.to_numpy()[0], this_event_new.longitude.to_numpy()[0])
    coords_2 = (47.6531, -122.3079)
    dist_km = geopy.distance.geodesic(coords_1, coords_2).km
    
    #distance = haversine(longitude_loc,latitude_loc,longitude_ref,latitude_ref)
    
    #if distance < 500:
    #    continue
    magnituddarray.append(this_event_new['magnitude'].to_numpy()[0])
    dist_kmarray.append(dist_km)
    print(this_event['id'])
    
    stitle=f"M {this_event_new['magnitude'].to_numpy()[0]}, "\
           f"{this_event_new['location'].to_numpy()[0]}, "\
           f"{str(this_event_new['time'].to_numpy()[0])[0:-10]} UTC"
      

        
    cable = 'whidbey'
    record_length = 5 #minutes
    t0 = this_event_new['time'].iloc[0]
    
    prefix, network_name, datastore = data_wrangler(cable,record_length,t0)
        
    try:
        data,dates,attrs = open_sintela_file(prefix,
                                             t0,
                                             datastore,
                                             number_of_files=record_length,
                                             verbose=True)
        #x_max=data.shape[1] * attrs['SpatialSamplingInterval']

        #low_cut = 2
        #hi_cut = 10

        #b,a = butter(2,(low_cut,hi_cut),'bp',fs=attrs['MaximumFrequency']*2)
        #data_filt = filtfilt(b,a,data,axis=0)
        #try:
            #client = Client("IRIS")

            #t1 = UTCDateTime( t0.strftime("%Y-%m-%dT%H:%M:%S") )
            #dt = datetime.timedelta(minutes=record_length)
            #t2 = UTCDateTime( (t0+dt).strftime("%Y-%m-%dT%H:%M:%S") )

            #st = client.get_waveforms("UW", "NOWS", "--", "HNN", t1, t2, attach_response=True)
            # st.decimate(5, strict_length=False, no_filter=False) #everything should be at 40Hz now
            #st2 = client.get_waveforms("IU", "COR", "00", "HH1", t1, t2, attach_response=True)

            #pre_filt = (low_cut/2, low_cut, hi_cut, hi_cut*2)
            #st.remove_response(output='VEL', pre_filt=pre_filt)
            #st2.remove_response(output='VEL', pre_filt=pre_filt)
        
        #filename = f"earthquakes_distances600noseismogramsseadas/"+this_id
        #local_earthquake_quicklook(dates,data_filt,0,0,x_max,
                        #stitle,filename=filename,das_vmax=0.1,
                          # network_name=network_name,
                          #skip_seismograms=True)
        #except Exception as e:
        #     print(str(e))
       # continue
    except ValueError:
         continue
# Out:
# us7000j3g5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-12-28_08-07*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-12-28_08-08*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-12-28_08-09*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-12-28_08-10*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-12-28_08-11*h5
# us7000j3f8
# Searching for files matching: /data/data6/whidbey/whidbey_2022-12-28_08-06*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-12-28_08-07*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-12-28_08-08*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-12-28_08-09*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-12-28_08-10*h5
# us7000ishe
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-26_03-50*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-26_03-51*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-26_03-52*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-26_03-53*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-26_03-54*h5
# us7000iqsk
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-18_15-42*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-18_15-43*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-18_15-44*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-18_15-45*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-18_15-46*h5
# us7000imha
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-04_14-16*h5
# us7000im59
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-03_09-57*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-03_09-58*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-03_09-59*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-03_10-00*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-03_10-01*h5
# us7000ikhh
# Searching for files matching: /data/data6/whidbey/whidbey_2022-10-26_15-18*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-10-26_15-19*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-10-26_15-20*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-10-26_15-21*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-10-26_15-22*h5
# us6000itsl
# Searching for files matching: /data/data5/Converted/whidbey_2022-10-14_21-23*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-10-14_21-24*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-10-14_21-25*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-10-14_21-26*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-10-14_21-27*h5
# uw61886506
# Searching for files matching: /data/data5/Converted/whidbey_2022-10-07_12-52*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-10-07_12-53*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-10-07_12-54*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-10-07_12-55*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-10-07_12-56*h5
# us6000ipd3
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-29_15-09*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-29_15-10*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-29_15-11*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-29_15-12*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-29_15-13*h5
# uw61882431
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-22_14-41*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-22_14-42*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-22_14-43*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-22_14-44*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-22_14-45*h5
# us7000ia3v
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-22_08-47*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-22_08-48*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-22_08-49*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-22_08-50*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-22_08-51*h5
# us7000i88d
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-15_09-21*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-15_09-22*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-15_09-23*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-15_09-24*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-15_09-25*h5
# uw61869652
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-08_08-08*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-08_08-09*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-08_08-10*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-08_08-11*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-08_08-12*h5
# us7000i36x
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-28_21-26*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-28_21-27*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-28_21-28*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-28_21-29*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-28_21-30*h5
# uw61862977
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-13_13-31*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-13_13-32*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-13_13-33*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-13_13-34*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-13_13-35*h5
# us6000iac9
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-12_20-00*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-12_20-01*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-12_20-02*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-12_20-03*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-12_20-04*h5
# us6000iabx
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-12_19-14*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-12_19-15*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-12_19-16*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-12_19-17*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-12_19-18*h5
# us6000i90r
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-08_07-38*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-08_07-39*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-08_07-40*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-08_07-41*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-08_07-42*h5
# uw61860022
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-04_13-22*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-04_13-23*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-04_13-24*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-04_13-25*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-08-04_13-26*h5
# us6000hziu
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-03_10-42*h5
# uw61836427
# Searching for files matching: /data/data5/Converted/whidbey_2022-05-28_19-07*h5
# us6000hn38
# Searching for files matching: /data/data5/Converted/whidbey_2022-05-22_09-58*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-05-22_09-59*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-05-22_10-00*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-05-22_10-01*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-05-22_10-02*h5
# uw61832097
# Searching for files matching: /data/data5/Converted/whidbey_2022-05-17_08-07*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-05-17_08-08*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-05-17_08-09*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-05-17_08-10*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-05-17_08-11*h5
# us7000h76t
# Searching for files matching: /data/data5/Converted/whidbey_2022-05-05_03-38*h5
# uw61835766
# Searching for files matching: /data/data5/Converted/whidbey_2022-05-01_11-15*h5
# us7000h3bv
# Searching for files matching: /data/data5/Converted/whidbey_2022-04-19_12-43*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-04-19_12-44*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-04-19_12-45*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-04-19_12-46*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-04-19_12-47*h5
# us7000h21e
# Searching for files matching: /data/data5/Converted/whidbey_2022-04-14_01-21*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-04-14_01-22*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-04-14_01-23*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-04-14_01-24*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-04-14_01-25*h5

# %%
#creating plot distance vs magnitud
plt.subplots(figsize=(10,5))
plt.scatter(np.log(dist_kmarray), magnituddarray,s=None, marker='o', alpha=0.9, label='Different earthquakes')
plt.xlabel('Distance to the cable [Km]')
plt.ylabel('Earthquakes magnitud');
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Data frame for earthquakes with WhibdeyCable

# %%
tf=['False','False','True','True','norecord','True','False','True','True','True','False','True','True','False','False','False','False','False','False','True','Norecord','Norecord','False','True','Norecord','Norecord','True','False']
tfn=np.array(tf).T
len(tf)
dataf = np.array([event_df.id, event_df.location, event_df.magnitude,tf],dtype='object').T
dataf

df3 = pd.DataFrame(dataf,columns=['Id', 'Distance', 'Magnitude','Detected by Das'])
df3
# Out:
#             Id                               Distance Magnitude  \
# 0   us7000j3g5            off the coast of Washington       3.9
# 1   us7000j3f8            267 km SW of Tofino, Canada       3.8
# 2   us7000ishe             18 km NW of Tofino, Canada       4.9
# 3   us7000iqsk                off the coast of Oregon       4.4
# 4   us7000imha                Off the coast of Oregon       3.4
# 5   us7000im59                Off the coast of Oregon       3.5
# 6   us7000ikhh           169 km W of Langlois, Oregon       3.2
# 7   us6000itsl      152 km WNW of Port Orford, Oregon       3.3
# 8   uw61886506            16 km ESE of Lacomb, Oregon      4.39
# 9   us6000ipd3            off the coast of Washington       3.3
# 10  uw61882431         26 km WNW of Forks, Washington      3.49
# 11  us7000ia3v             225 km W of Bandon, Oregon       3.9
# 12  us7000i88d             151 km W of Bandon, Oregon       4.4
# 13  uw61869652         7 km WNW of Lofall, Washington      3.71
# 14  us7000i36x           188 km WNW of Bandon, Oregon       3.3
# 15  uw61862977      21 km NW of Bickleton, Washington      3.05
# 16  us6000iac9            148 km W of Yachats, Oregon       4.0
# 17  us6000iabx                off the coast of Oregon       3.1
# 18  us6000i90r             201 km W of Tofino, Canada       4.6
# 19  uw61860022  6 km SSE of Black Diamond, Washington      3.06
# 20  us6000hziu        9 km WNW of Smiths Ferry, Idaho       3.1
# 21  uw61836427    55 km NE of Marblemount, Washington      3.16
# 22  us6000hn38              2 km WSW of Mullan, Idaho       3.0
# 23  uw61832097            6 km ENE of Oso, Washington       3.4
# 24  us7000h76t           233 km WSW of Tofino, Canada       4.1
# 25  uw61835766     2 km E of Mount Vernon, Washington      3.56
# 26  us7000h3bv             191 km W of Bandon, Oregon       3.9
# 27  us7000h21e         132 km WNW of Langlois, Oregon       4.2
#
#    Detected by Das
# 0            False
# 1            False
# 2             True
# 3             True
# 4         norecord
# 5             True
# 6            False
# 7             True
# 8             True
# 9             True
# 10           False
# 11            True
# 12            True
# 13           False
# 14           False
# 15           False
# 16           False
# 17           False
# 18           False
# 19            True
# 20        Norecord
# 21        Norecord
# 22           False
# 23            True
# 24        Norecord
# 25        Norecord
# 26            True
# 27           False

# %%
#creating plot distance vs magnitud (real earthquakes that we can see)
newmagtnitud=[magnituddarray[2],magnituddarray[3],magnituddarray[5],magnituddarray[7],magnituddarray[8],magnituddarray[10],magnituddarray[11],magnituddarray[13],magnituddarray[14],magnituddarray[18],magnituddarray[19],magnituddarray[23],magnituddarray[26]]
newdist_kmarray=[dist_kmarray[2],dist_kmarray[3],dist_kmarray[5],dist_kmarray[7],dist_kmarray[8],dist_kmarray[10],dist_kmarray[11],dist_kmarray[13],dist_kmarray[14],dist_kmarray[18],dist_kmarray[19],dist_kmarray[23],dist_kmarray[26]]
filename = f"earthquakes_distances600noseismogramswhidbey/"
figure=plt.plot(figsize=(10,5))
plt.scatter(np.log10(newdist_kmarray),newmagtnitud,s=None, marker='o', alpha=0.9, label='Different earthquakes')
plt.title('Locas/regional earthquakes that the Whidbey cable can detect')
plt.xlabel('log(Distance to the cable [Km])')
plt.ylabel('Earthquakes magnitud');
plt.legend()
plt.grid()
#plt.savefig(filename+"_whidbeylocalquakes")
plt.savefig("whidbeylocalquakes")
plt.show()
plt.close()
