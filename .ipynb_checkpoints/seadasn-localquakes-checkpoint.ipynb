# %% [markdown]
# # Earthquake seismology with DAS
#
# #### Todo List:
# 1. Reference earthquakes by Evid rather than dataframe index
# 2. Make a map of all of the detected events
# 3. Try some xcorr
# 4. Focal Mechanisms

# %%
import h5py
import matplotlib.pyplot as plt
from scipy.signal import butter, filtfilt
import numpy as np
import datetime
import pandas as pd
from dasquakes import sintela_to_datetime, open_sintela_file, get_file_number, local_earthquake_quicklook, data_quicklook 
import obspy
from obspy import UTCDateTime
from obspy.clients.fdsn import Client
from libcomcat.search import search
from libcomcat.dataframes import get_summary_data_frame
from tqdm import tqdm

# %% [markdown]
# ### Get a list of events from USGS

# %%
events = search(starttime = datetime.datetime(2022, 3, 17, 0, 0), 
                endtime   = datetime.datetime.now(),
                maxradiuskm=1000, 
                latitude=47.60, 
                longitude=-122.33)

#events = search(starttime = datetime.datetime(2022, 9, 7, 0, 0), 
#                endtime   = datetime.datetime(2022, 9, 9, 0, 0),
#                maxradiuskm=1000, 
#                latitude=47.60, 
#                longitude=-122.33)

print("Returned %s events" % len(events))
# Out:
# Returned 16485 events

# %%
event_df = get_summary_data_frame(events)
event_df = event_df.sort_values(by=['magnitude'],ascending=False)
event_df.iloc[0:20]
# Out:
#                id                    time                            location  \
# 6028   us7000hhik 2022-06-15 11:56:33.191             off the coast of Oregon
# 2848   us6000hfx7 2022-04-23 21:22:47.948    185 km W of Port McNeill, Canada
# 5461   us7000hf29 2022-06-04 23:59:10.007          Haida Gwaii Region, Canada
# 768    us7000gxl1 2022-03-27 01:12:22.059             off the coast of Oregon
# 12729  nc73785481 2022-09-24 19:27:39.450              37km W of Petrolia, CA
# 9062   us6000i90r 2022-08-08 07:38:56.410          201 km W of Tofino, Canada
# 5945   us7000hh4b 2022-06-13 17:34:43.012    204 km W of Port McNeill, Canada
# 8264   us7000hth5 2022-07-26 05:46:22.180          Haida Gwaii Region, Canada
# 11748  us7000i88d 2022-09-15 09:21:38.195             off the coast of Oregon
# 6032   us7000hhiy 2022-06-15 13:18:41.414             off the coast of Oregon
# 1754   us7000h0vb 2022-04-09 07:51:48.789             off the coast of Oregon
# 9587   us6000ibfj 2022-08-16 21:03:23.030  202 km WSW of Pistol River, Oregon
# 10549  us7000i3dm 2022-08-29 15:22:29.115    216 km W of Ferndale, California
# 13738  uw61886506 2022-10-07 12:52:36.010         16 km ESE of Lacomb, Oregon
# 14793  nc73796766 2022-10-20 07:55:16.770               36km NE of Redway, CA
# 9146   us6000i9du 2022-08-09 14:40:47.726  197 km WSW of Pistol River, Oregon
# 6030   us7000hhir 2022-06-15 12:50:16.970                                None
# 9389   us6000iakl 2022-08-13 18:45:28.484    197 km W of Pistol River, Oregon
# 8112   nc73761796 2022-07-23 01:41:04.680          5km S of Oroville East, CA
# 2054   us7000h21e 2022-04-14 01:21:15.822      132 km WNW of Langlois, Oregon
#
#         latitude   longitude  depth  magnitude  alert  \
# 6028   44.538100 -130.112400  10.00       5.60  green
# 2848   50.472500 -129.689500  10.00       5.30   None
# 5461   51.613700 -131.402700   6.61       5.10   None
# 768    44.122900 -129.438500  10.00       5.10   None
# 12729  40.313667 -124.724500  13.08       4.84  green
# 9062   48.973600 -128.652200  10.00       4.60   None
# 5945   50.920200 -129.941400  10.00       4.60   None
# 8264   51.687200 -131.193100  10.00       4.60   None
# 11748  43.243600 -126.265300  10.00       4.40   None
# 6032   44.505800 -130.151400  10.00       4.40   None
# 1754   44.215900 -129.166200  10.00       4.40   None
# 9587   41.890500 -126.785300  10.00       4.40   None
# 10549  40.408300 -126.812200  10.00       4.40   None
# 13738  44.540333 -122.550833  13.17       4.39  green
# 14793  40.349500 -123.518500  33.05       4.32  green
# 9146   41.877400 -126.725600  10.00       4.30   None
# 6030   44.576600 -129.908500  10.00       4.30   None
# 9389   42.025200 -126.764500  10.00       4.30   None
# 8112   39.465667 -121.476167   0.59       4.24  green
# 2054   43.173900 -126.045300  10.00       4.20   None
#
#                                                      url   eventtype  \
# 6028   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 2848   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 5461   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 768    https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 12729  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 9062   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 5945   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 8264   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 11748  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 6032   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 1754   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 9587   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 10549  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 13738  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 14793  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 9146   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 6030   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 9389   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 8112   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 2054   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
#
#        significance
# 6028            487
# 2848            435
# 5461            401
# 768             404
# 12729           461
# 9062            326
# 5945            326
# 8264            326
# 11748           300
# 6032            298
# 1754            298
# 9587            298
# 10549           299
# 13738           896
# 14793           321
# 9146            285
# 6030            285
# 9389            284
# 8112            528
# 2054            272

# %% [markdown]
# ### Choose an event to analyze

# %%
detected_quakes = ['uw61835766','uw61832097','uw61836427',
                   'uw61846212','uw61819867','uw61850651','uw61855012']
# detected_quakes_whidbey = ['uw61832097','uw61819867','uw61855012','us7000gxl1']

# this_event_index = 0
# this_id=detected_quakes[this_event_index]

this_id = 'us7000hhik'

this_event = event_df[event_df.id==this_id]
t0 = this_event['time'].iloc[0]

this_event
# Out:
#               id                    time                 location  latitude  \
# 6028  us7000hhik 2022-06-15 11:56:33.191  off the coast of Oregon   44.5381
#
#       longitude  depth  magnitude  alert  \
# 6028  -130.1124   10.0        5.6  green
#
#                                                     url   eventtype  \
# 6028  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
#
#       significance
# 6028           487

# %% [markdown]
# ### Load the DAS Data

# %%
cable = 'seadasn'
#cable = 'whidbey'
record_length = 10 #minutes

if cable == 'seadasn':
    prefix = 'seadasn'
    network_name = 'SeaDAS-N'
    if t0 < datetime.datetime(2022, 6, 20, 0, 0, 0):
        datastore='/data/data0/seadasn_2022-03-17_2022-06-20/'
    else:
        datastore='/data/data7/seadasn/'
        
elif cable == 'whidbey':
    prefix = 'whidbey'
    network_name='Whidbey-DAS'
    datastore = '/data/data5/Converted/'

data,dates,attrs = open_sintela_file(prefix,
                                     t0,
                                     datastore,
                                     number_of_files=record_length,
                                     verbose=True)
x_max=data.shape[1] * attrs['SpatialSamplingInterval']
# Out:
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-15_11-56*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-15_11-57*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-15_11-58*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-15_11-59*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-15_12-00*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-15_12-01*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-15_12-02*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-15_12-03*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-15_12-04*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-15_12-05*.h5

# %%
data
# Out:
# array([[ 2.4455104 ,  0.7069179 ,  0.8545533 , ...,  0.1908038 ,
#          0.213634  ,  0.18717828],
#        [ 2.4728365 ,  0.57969916,  1.5263572 , ...,  0.19497253,
#          0.21116981,  0.21097247],
#        [ 2.5199878 ,  0.2618932 ,  0.9522387 , ...,  0.17700034,
#          0.22061262,  0.20576084],
#        ...,
#        [-3.81151   ,  0.4448767 ,  0.7053587 , ..., -0.18556654,
#         -0.18827406, -0.19702104],
#        [-3.7844563 ,  0.42788637,  0.8527104 , ..., -0.18574826,
#         -0.1890963 , -0.18321489],
#        [-3.7565649 , -0.7915309 , -0.5963481 , ..., -0.14837289,
#         -0.19604678, -0.19224782]], dtype=float32)

# %%
low_cut = 0.01
hi_cut = 2

b,a = butter(2,(low_cut,hi_cut),'bp',fs=attrs['MaximumFrequency']*2)
data_filt = filtfilt(b,a,data,axis=0)

# %%
client = Client("IRIS")

t1 = UTCDateTime( t0.strftime("%Y-%m-%dT%H:%M:%S") )
dt = datetime.timedelta(minutes=record_length)
t2 = UTCDateTime( (t0+dt).strftime("%Y-%m-%dT%H:%M:%S") )

st = client.get_waveforms("UW", "NOWS", "--", "HNN", t1, t2, attach_response=True)
# st.decimate(5, strict_length=False, no_filter=False) #everything should be at 40Hz now
st2 = client.get_waveforms("IU", "COR", "00", "HH1", t1, t2, attach_response=True)

pre_filt = (low_cut/2, low_cut, hi_cut, hi_cut*2)
st.remove_response(output='VEL', pre_filt=pre_filt)
st2.remove_response(output='VEL', pre_filt=pre_filt)
# Out:
# 1 Trace(s) in Stream:
# IU.COR.00.HH1 | 2022-06-15T11:56:33.008393Z - 2022-06-15T12:06:32.998393Z | 100.0 Hz, 60000 samples

# %%
stitle=f"M {this_event['magnitude'].to_numpy()[0]}, "\
       f"{this_event['location'].to_numpy()[0]}, "\
       f"{str(this_event['time'].to_numpy()[0])[0:-10]} UTC"

data_quicklook(dates,data_filt,x_max,stitle,filename=None,das_vmax=0.02,network_name=network_name,ylim=[0,1000])

# %%
# nombre = f"figures/{event_df.iloc[catalog_index]['Evid']}.png"
# local_earthquake_quicklook(dates,data_filt,st,st2,x_max,event_df,catalog_index,filename=nombre)

#vmax=0.02
stitle=f"M {this_event['magnitude'].to_numpy()[0]}, "\
       f"{this_event['location'].to_numpy()[0]}, "\
       f"{str(this_event['time'].to_numpy()[0])[0:-10]} UTC"


local_earthquake_quicklook(dates,data_filt,st,st2,x_max,
                           stitle,das_vmax=0.02,
                           network_name=network_name)

# %%
    low_cut = 0.01
    hi_cut = 2

    b,a = butter(2,(low_cut,hi_cut),'bp',fs=attrs['MaximumFrequency']*2)
    data_filt = filtfilt(b,a,data,axis=0)
    
    import matplotlib.dates as mdates
    dx = x_max / data_filt.shape[1]
    fig,ax=plt.subplots(figsize=(10,10))
    date_format = mdates.DateFormatter('%H:%M:%S')
    
    ax = plt.subplot(4,1,1)
    fig.patch.set_facecolor('w')
    graph_spacing = -20
    #,400,800,1400
    jj=41
    plt.plot(dates,data_filt[:,jj]-jj/graph_spacing,label=f'OD = {int(jj*dx)} m')
    plt.legend(loc='upper right')
    ax.set_title(f'{network_name} Individual Channels')
    ax.xaxis.set_major_formatter(date_format)
    ax.xaxis_date()
    ax.autoscale(enable=True, axis='x', tight=True)
    plt.grid()

# %%
this_event.url.to_list()[0]
len(data_filt)
data_filt
# Out:
# array([[-1.27892308, -0.17736357,  0.30101493, ...,  0.02891749,
#          0.0370224 ,  0.03196922],
#        [-1.26835507, -0.20254599,  0.32199089, ...,  0.02938814,
#          0.03693097,  0.03314533],
#        [-1.25768106, -0.2270319 ,  0.34267436, ...,  0.0298721 ,
#          0.03682338,  0.0343103 ],
#        ...,
#        [-0.08193884,  0.55924083,  0.54214897, ..., -0.02965661,
#         -0.00433689, -0.01290474],
#        [-0.07226202,  0.49474965,  0.47961447, ..., -0.02608248,
#         -0.00369753, -0.01130126],
#        [-0.06291827,  0.43088498,  0.41769273, ..., -0.0226073 ,
#         -0.0031379 , -0.00978034]])

# %%
from tqdm import tqdm
xc = np.zeros((119999,174))

for i in tqdm(range(174)):
    xc[:,i] = np.correlate(np.sign(data_filt[:,30]),
                           np.sign(data_filt[:,i*10]),
                           mode='full')
# Out:
# 100%|██████████| 174/174 [07:32<00:00,  2.60s/it]

# %%
fig,ax=plt.subplots()
plt.imshow(xc.T,aspect='auto')#,vmin=-1000,vmax=1000)
# plt.plot(data_filt[:,30])
# plt.plot(data_filt[:,40])
plt.xlim(18000-1e3,18000+1e3)
plt.colorbar()

# %%
xc.A
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1178487/1191774840.py in <module>
# ----> 1 xc.A
#
# AttributeError: 'numpy.ndarray' object has no attribute 'A'

# %%
fig,ax=plt.subplots()
# plt.imshow(xc.T,aspect='auto',vmin=-0.1,vmax=0.1)
plt.plot(data_filt[:,40])
plt.plot(data_filt[:,30],alpha=0.5)
plt.xlim(6000,8000)
plt.show()

# %%
open 'local_earthquake_quicklook'
