# %% [markdown]
# # Earthquake seismology with DAS
#
# #### Todo List:
# 1. Reference earthquakes by Evid rather than dataframe index
# 2. Make a map of all of the detected events
# 3. Try some xcorr
# 4. Find something for JM to do

# %%
import h5py
import matplotlib.pyplot as plt
from scipy.signal import butter, filtfilt
import numpy as np
import datetime
import pandas as pd
from dasquakes import sintela_to_datetime, open_sintela_file, get_file_number, local_earthquake_quicklook
import obspy
from obspy import UTCDateTime
from obspy.clients.fdsn import Client
from libcomcat.search import search
from libcomcat.dataframes import get_summary_data_frame

# %% [markdown]
# ### Get a list of events from USGS

# %%
events = search(starttime = datetime.datetime(2022, 3, 17, 0, 0), 
                endtime   = datetime.datetime.now(),
                maxradiuskm=50, 
                latitude=47.60, 
                longitude=-122.33)

print("Returned %s events" % len(events))
# Out:
# Returned 159 events

# %%
event_df = get_summary_data_frame(events)
event_df = event_df.sort_values(by=['magnitude'],ascending=False)
event_df.iloc[0:5]
# Out:
#              id                    time  \
# 474  uw61869652 2022-09-08 08:08:25.830
# 116  uw61835766 2022-05-01 11:15:56.460
# 167  uw61832097 2022-05-17 08:07:34.400
# 383  uw61860022 2022-08-04 13:22:39.400
# 290  uw61846212 2022-06-25 20:18:40.160
#
#                                   location   latitude   longitude  depth  \
# 474         7 km WNW of Lofall, Washington  47.842000 -122.751667  23.33
# 116     2 km E of Mount Vernon, Washington  48.423500 -122.305500  13.54
# 167            6 km ENE of Oso, Washington  48.299667 -121.852000   3.53
# 383  6 km SSE of Black Diamond, Washington  47.258667 -121.971833  21.54
# 290            5 km ENE of Oso, Washington  48.294167 -121.863500   6.29
#
#      magnitude alert                                                url  \
# 474       3.71  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 116       3.56  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 167       3.40  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 383       3.06  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 290       2.95  None  https://earthquake.usgs.gov/earthquakes/eventp...
#
#       eventtype  significance
# 474  earthquake           592
# 116  earthquake           424
# 167  earthquake           280
# 383  earthquake           250
# 290  earthquake           154

# %% [markdown]
# ### Choose an event to analyze

# %%
detected_quakes = ['uw61869652','uw61860022','uw61847792',
                   'uw61846087','uw61834816']
# detected_quakes_whidbey = ['uw61832097','uw61819867','uw61855012','us7000gxl1']

# this_event_index = 0
# this_id=detected_quakes[this_event_index]

this_id = 'uw61835766'

this_event = event_df[event_df.id==this_id]
t0 = this_event['time'].iloc[0]

this_event
# Out:
#              id                    time                            location  \
# 116  uw61835766 2022-05-01 11:15:56.460  2 km E of Mount Vernon, Washington
#
#      latitude  longitude  depth  magnitude alert  \
# 116   48.4235  -122.3055  13.54       3.56  None
#
#                                                    url   eventtype  \
# 116  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
#
#      significance
# 116           424

# %% [markdown]
# ### Load the DAS Data

# %%
# cable = 'seadasn'
cable = 'seadasn'
record_length = 10 #minutes

if cable == 'seadasn':
    prefix = 'seadasn'
    network_name = 'SeaDAS-N'
    if t0 < datetime.datetime(2022, 6, 20, 0, 0, 0):
        datastore='/data/data0/seadasn_2022-03-17_2022-06-20/'
    else:
        datastore='/data/data7/seadasn/'
        
elif cable == 'whidbey':
    prefix = 'whidbey'
    network_name='Whidbey-DAS'
    datastore = '/data/data5/Converted/'

data,dates,attrs = open_sintela_file(prefix,
                                     t0,
                                     datastore,
                                     number_of_files=record_length,
                                     verbose=True)
x_max=data.shape[1] * attrs['SpatialSamplingInterval']
# Out:
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-01_11-15*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-01_11-16*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-01_11-17*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-01_11-18*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-01_11-19*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-01_11-20*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-01_11-21*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-01_11-22*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-01_11-23*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-01_11-24*.h5

# %%
low_cut = 2
hi_cut = 10

b,a = butter(2,(low_cut,hi_cut),'bp',fs=attrs['MaximumFrequency']*2)
data_filt = filtfilt(b,a,data,axis=0)

# %%
client = Client("IRIS")

t1 = UTCDateTime( t0.strftime("%Y-%m-%dT%H:%M:%S") )
dt = datetime.timedelta(minutes=record_length)
t2 = UTCDateTime( (t0+dt).strftime("%Y-%m-%dT%H:%M:%S") )

st = client.get_waveforms("UW", "NOWS", "--", "HNN", t1, t2, attach_response=True)
# st.decimate(5, strict_length=False, no_filter=False) #everything should be at 40Hz now
st2 = client.get_waveforms("IU", "COR", "00", "HH1", t1, t2, attach_response=True)

pre_filt = (low_cut/2, low_cut, hi_cut, hi_cut*2)
st.remove_response(output='VEL', pre_filt=pre_filt)
st2.remove_response(output='VEL', pre_filt=pre_filt)
# Out:
# 1 Trace(s) in Stream:
# IU.COR.00.HH1 | 2022-05-01T11:15:56.008393Z - 2022-05-01T11:25:55.998393Z | 100.0 Hz, 60000 samples

# %%
# nombre = f"figures/{event_df.iloc[catalog_index]['Evid']}.png"
# local_earthquake_quicklook(dates,data_filt,st,st2,x_max,event_df,catalog_index,filename=nombre)


stitle=f"M {this_event['magnitude'].to_numpy()[0]}, "\
       f"{this_event['location'].to_numpy()[0]}, "\
       f"{str(this_event['time'].to_numpy()[0])[0:-10]} UTC"


local_earthquake_quicklook(dates,data_filt,st,st2,x_max,
                           stitle,das_vmax=0.02,
                           network_name=network_name)

# %%
this_event.url.to_list()[0]
# Out:
# 'https://earthquake.usgs.gov/earthquakes/eventpage/uw61835766'

# %%
# from tqdm import tqdm
# xc = np.zeros((2*18000-1,174))

# for i in tqdm(range(174)):
#     xc[:,i] = np.correlate( data_filt[:,30]/max(data_filt[:,30]),
#                             data_filt[:,i*10]/max(data_filt[:,i*10]),
#                             mode='full')

# %%
from tqdm import tqdm
xc = np.zeros((2*18000-1,174))

for i in tqdm(range(174)):
    xc[:,i] = np.correlate(np.sign(data_filt[:,30]),
                           np.sign(data_filt[:,i*10]),
                           mode='full')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_647607/195142327.py in <module>
# ----> 1 from tqdm import tqdm
#       2 xc = np.zeros((2*18000-1,174))
#       3
#       4 for i in tqdm(range(174)):
#       5     xc[:,i] = np.correlate(np.sign(data_filt[:,30]),
#
# ModuleNotFoundError: No module named 'tqdm'

# %%
fig,ax=plt.subplots()
plt.imshow(xc.T,aspect='auto',vmin=-1000,vmax=1000)
# plt.plot(data_filt[:,30])
# plt.plot(data_filt[:,40])
plt.xlim(18000-1e3,18000+1e3)
plt.show()

# %%
fig,ax=plt.subplots()
# plt.imshow(xc.T,aspect='auto',vmin=-0.1,vmax=0.1)
plt.plot(data_filt[:,40])
plt.plot(data_filt[:,30],alpha=0.5)
plt.xlim(7050,7200)
plt.ylim(-0.5,0.5)
plt.show()

# %%
fig,ax=plt.subplots()

for i in data_filt.T[30:100]:
    ax.plot(i, c='grey', alpha=0.1)
plt.xlim([6800,12000])
plt.ylim([-1,1])
plt.show()

# %%
from scipy.fft import fft, ifft
af = fft(data_filt[:,11])
bf = fft(data_filt[:,60])
c = ifft(af * scipy.conj(bf))

time_shift = np.argmax(c)
print(time_shift)
# Out:
# 4
# /home/jmanos/miniconda3/envs/comcat/lib/python3.7/site-packages/ipykernel_launcher.py:4: DeprecationWarning: scipy.conj is deprecated and will be removed in SciPy 2.0.0, use numpy.conj instead
#   after removing the cwd from sys.path.

# %%
import obspy.core.trace 
das_trace = obspy.core.trace.Trace(data_filt[:,400])
das_trace.plot()

# %%
das_trace.stats['sampling_rate'] = 100.0

# %%
das_trace.stats.sampling_rate
# Out:
# 100.0

# %%
from obspy.signal.trigger import classic_sta_lta
from obspy.signal.trigger import plot_trigger

df = das_trace.stats.sampling_rate
cft = classic_sta_lta(c, int(6 * df), int(10 * df))

plot_trigger(das_trace, cft, 1.5, 0.5)

# %%
print(cft.argmax())
# Out:
# 7646

# %%
channel_picks = []
chan_number = 0

for channel in data_filt.T:
    das_trace = obspy.core.trace.Trace(channel)
    das_trace.stats['sampling_rate'] = 100.0
    df = das_trace.stats.sampling_rate
    cft = classic_sta_lta(das_trace, int(5 * df), int(10 * df))
    
    channel_picks.append( cft.argmax() / 100 )
    
    chan_number +=1

# %%
channel_picks
# Out:
# [80.43,
#  599.3,
#  356.74,
#  426.59,
#  589.55,
#  89.1,
#  78.04,
#  359.25,
#  199.42,
#  397.04,
#  578.76,
#  599.76,
#  88.41,
#  599.98,
#  78.17,
#  89.3,
#  79.74,
#  80.13,
#  398.18,
#  139.53,
#  384.88,
#  438.46,
#  552.05,
#  577.96,
#  330.52,
#  292.17,
#  438.43,
#  285.1,
#  74.98,
#  76.04,
#  421.32,
#  76.2,
#  76.2,
#  76.1,
#  76.33,
#  75.95,
#  76.49,
#  76.19,
#  76.07,
#  76.19,
#  76.18,
#  75.96,
#  76.07,
#  75.96,
#  75.98,
#  75.99,
#  76.0,
#  76.0,
#  76.15,
#  76.0,
#  505.73,
#  87.93,
#  76.13,
#  76.09,
#  76.0,
#  75.9,
#  75.9,
#  75.82,
#  75.69,
#  75.89,
#  75.7,
#  75.7,
#  75.77,
#  75.78,
#  75.99,
#  76.04,
#  76.03,
#  76.16,
#  76.01,
#  76.0,
#  75.93,
#  75.93,
#  76.16,
#  75.94,
#  75.65,
#  76.01,
#  75.66,
#  75.61,
#  75.65,
#  75.69,
#  75.68,
#  75.7,
#  75.88,
#  76.01,
#  75.94,
#  75.84,
#  75.95,
#  75.96,
#  75.96,
#  75.96,
#  75.96,
#  76.02,
#  76.09,
#  75.75,
#  75.76,
#  75.96,
#  75.96,
#  75.96,
#  75.95,
#  75.99,
#  86.14,
#  76.22,
#  76.03,
#  75.86,
#  75.96,
#  75.95,
#  75.97,
#  76.11,
#  76.11,
#  76.01,
#  75.96,
#  75.96,
#  75.83,
#  75.83,
#  75.84,
#  75.92,
#  554.62,
#  76.04,
#  75.79,
#  75.9,
#  75.9,
#  75.97,
#  75.97,
#  75.98,
#  75.98,
#  76.0,
#  76.04,
#  75.94,
#  76.11,
#  76.42,
#  75.93,
#  75.9,
#  75.91,
#  75.91,
#  75.98,
#  75.96,
#  75.98,
#  76.0,
#  75.93,
#  76.04,
#  76.01,
#  76.02,
#  76.03,
#  76.06,
#  75.93,
#  75.93,
#  75.95,
#  75.96,
#  75.96,
#  75.97,
#  345.3,
#  343.84,
#  76.08,
#  452.07,
#  75.92,
#  75.94,
#  75.98,
#  75.96,
#  75.97,
#  75.97,
#  76.03,
#  75.92,
#  75.91,
#  75.91,
#  75.91,
#  76.01,
#  75.44,
#  75.79,
#  75.79,
#  296.92,
#  75.55,
#  76.05,
#  75.97,
#  75.52,
#  75.61,
#  75.53,
#  75.64,
#  75.88,
#  75.9,
#  76.07,
#  76.08,
#  75.97,
#  75.95,
#  75.95,
#  76.19,
#  75.92,
#  75.96,
#  75.97,
#  75.95,
#  75.95,
#  76.02,
#  76.11,
#  75.74,
#  75.73,
#  75.85,
#  341.03,
#  341.17,
#  76.0,
#  418.53,
#  340.66,
#  478.47,
#  341.8,
#  250.86,
#  86.12,
#  582.8,
#  581.99,
#  12.81,
#  578.85,
#  58.45,
#  378.18,
#  201.48,
#  87.86,
#  87.85,
#  362.5,
#  249.43,
#  544.5,
#  253.66,
#  248.09,
#  391.81,
#  557.92,
#  516.88,
#  434.38,
#  395.81,
#  481.78,
#  450.64,
#  321.67,
#  430.21,
#  73.41,
#  68.77,
#  157.09,
#  430.04,
#  558.59,
#  338.25,
#  408.12,
#  61.41,
#  88.01,
#  87.88,
#  319.52,
#  76.85,
#  75.96,
#  88.12,
#  87.96,
#  75.96,
#  75.92,
#  75.9,
#  75.69,
#  88.38,
#  316.61,
#  318.88,
#  514.39,
#  514.62,
#  513.87,
#  517.07,
#  75.87,
#  76.1,
#  75.91,
#  76.12,
#  75.39,
#  75.93,
#  75.99,
#  76.06,
#  75.81,
#  75.95,
#  75.41,
#  75.97,
#  76.35,
#  76.11,
#  76.11,
#  76.06,
#  76.02,
#  75.93,
#  76.02,
#  75.95,
#  76.0,
#  75.83,
#  76.08,
#  75.92,
#  76.0,
#  75.96,
#  75.93,
#  75.93,
#  75.93,
#  75.93,
#  75.82,
#  75.94,
#  75.82,
#  75.92,
#  75.91,
#  75.9,
#  75.86,
#  75.67,
#  276.28,
#  86.91,
#  278.91,
#  279.08,
#  278.85,
#  294.02,
#  278.84,
#  279.02,
#  278.98,
#  293.92,
#  75.22,
#  75.86,
#  76.04,
#  76.06,
#  275.82,
#  589.61,
#  590.58,
#  278.76,
#  280.02,
#  278.88,
#  282.31,
#  282.58,
#  278.72,
#  278.66,
#  277.79,
#  278.71,
#  277.9,
#  277.89,
#  275.35,
#  275.8,
#  275.46,
#  275.86,
#  275.66,
#  275.47,
#  275.84,
#  275.41,
#  275.62,
#  275.64,
#  275.82,
#  75.94,
#  75.98,
#  86.61,
#  86.75,
#  76.0,
#  75.51,
#  75.48,
#  473.49,
#  86.55,
#  28.3,
#  29.66,
#  579.4,
#  581.42,
#  85.93,
#  85.43,
#  85.58,
#  86.67,
#  75.75,
#  86.47,
#  75.85,
#  75.84,
#  548.32,
#  65.79,
#  75.82,
#  75.86,
#  75.86,
#  75.81,
#  75.86,
#  75.93,
#  75.82,
#  75.79,
#  75.8,
#  75.79,
#  75.82,
#  75.56,
#  75.69,
#  75.86,
#  75.68,
#  75.69,
#  75.68,
#  75.69,
#  75.67,
#  75.73,
#  75.71,
#  75.62,
#  75.71,
#  75.62,
#  75.91,
#  522.48,
#  520.62,
#  75.88,
#  325.64,
#  75.69,
#  75.27,
#  75.85,
#  75.83,
#  75.8,
#  75.79,
#  75.78,
#  75.78,
#  75.82,
#  75.81,
#  75.81,
#  75.78,
#  75.8,
#  75.8,
#  75.79,
#  75.76,
#  75.76,
#  75.79,
#  75.76,
#  75.76,
#  75.6,
#  75.76,
#  75.77,
#  75.78,
#  75.76,
#  75.77,
#  75.77,
#  75.55,
#  75.79,
#  75.81,
#  75.8,
#  75.79,
#  171.6,
#  171.6,
#  169.92,
#  169.9,
#  75.76,
#  75.77,
#  75.52,
#  75.81,
#  75.8,
#  75.79,
#  75.77,
#  477.29,
#  75.68,
#  481.28,
#  481.23,
#  75.77,
#  75.78,
#  75.78,
#  75.76,
#  75.76,
#  158.72,
#  158.61,
#  75.78,
#  75.79,
#  75.78,
#  75.77,
#  75.76,
#  75.74,
#  75.75,
#  75.74,
#  75.74,
#  75.75,
#  75.74,
#  75.74,
#  75.75,
#  75.73,
#  75.73,
#  75.73,
#  75.73,
#  75.73,
#  75.73,
#  75.74,
#  75.81,
#  75.8,
#  75.73,
#  75.72,
#  75.83,
#  75.83,
#  75.8,
#  75.83,
#  75.82,
#  75.81,
#  501.2,
#  501.39,
#  174.13,
#  402.21,
#  75.69,
#  75.71,
#  75.8,
#  75.76,
#  75.76,
#  75.76,
#  75.78,
#  75.69,
#  75.69,
#  75.7,
#  75.7,
#  75.69,
#  75.69,
#  75.63,
#  75.65,
#  75.65,
#  75.63,
#  75.62,
#  75.65,
#  75.65,
#  75.69,
#  75.7,
#  75.61,
#  75.61,
#  75.73,
#  75.73,
#  75.73,
#  75.84,
#  75.83,
#  75.81,
#  85.24,
#  85.01,
#  74.96,
#  75.37,
#  75.69,
#  75.68,
#  75.67,
#  75.59,
#  75.56,
#  75.6,
#  75.53,
#  74.9,
#  75.74,
#  75.74,
#  75.76,
#  75.81,
#  75.71,
#  75.77,
#  75.77,
#  75.78,
#  75.78,
#  75.79,
#  75.7,
#  75.76,
#  75.74,
#  75.73,
#  75.76,
#  75.74,
#  75.75,
#  75.74,
#  75.67,
#  75.66,
#  75.69,
#  75.66,
#  75.75,
#  75.74,
#  75.74,
#  75.72,
#  75.15,
#  75.57,
#  75.53,
#  75.53,
#  75.37,
#  75.74,
#  75.67,
#  75.6,
#  75.67,
#  75.5,
#  75.57,
#  75.01,
#  203.56,
#  205.39,
#  183.42,
#  75.47,
#  75.47,
#  75.67,
#  75.67,
#  75.66,
#  75.65,
#  75.49,
#  75.49,
#  75.37,
#  75.55,
#  383.38,
#  75.34,
#  75.44,
#  75.42,
#  75.13,
#  75.34,
#  75.33,
#  75.35,
#  75.04,
#  75.37,
#  75.38,
#  75.36,
#  75.38,
#  75.61,
#  75.52,
#  75.7,
#  75.69,
#  75.76,
#  75.32,
#  75.44,
#  75.41,
#  75.65,
#  75.74,
#  75.38,
#  75.23,
#  75.21,
#  75.47,
#  75.41,
#  75.56,
#  75.42,
#  75.43,
#  75.42,
#  75.61,
#  75.63,
#  74.97,
#  75.67,
#  75.65,
#  75.62,
#  75.62,
#  75.63,
#  75.63,
#  75.63,
#  75.59,
#  75.56,
#  75.63,
#  75.62,
#  75.64,
#  75.55,
#  75.52,
#  75.68,
#  75.77,
#  75.61,
#  75.63,
#  75.18,
#  87.11,
#  181.59,
#  75.62,
#  12.08,
#  85.92,
#  75.62,
#  86.93,
#  86.04,
#  75.56,
#  75.61,
#  75.73,
#  75.57,
#  75.34,
#  75.65,
#  75.27,
#  75.65,
#  75.55,
#  75.61,
#  75.63,
#  75.52,
#  75.62,
#  75.57,
#  75.45,
#  75.33,
#  75.15,
#  75.41,
#  74.83,
#  75.52,
#  74.66,
#  74.67,
#  75.04,
#  75.74,
#  75.71,
#  75.54,
#  75.11,
#  75.49,
#  75.53,
#  74.67,
#  75.63,
#  75.72,
#  75.68,
#  75.61,
#  75.62,
#  75.62,
#  75.58,
#  75.6,
#  75.42,
#  75.62,
#  75.62,
#  75.61,
#  75.62,
#  75.62,
#  75.28,
#  75.63,
#  75.72,
#  75.56,
#  75.65,
#  75.55,
#  75.52,
#  75.69,
#  75.59,
#  75.66,
#  75.65,
#  75.58,
#  75.66,
#  75.67,
#  75.67,
#  75.69,
#  75.67,
#  75.67,
#  75.7,
#  75.48,
#  75.59,
#  75.63,
#  75.68,
#  75.82,
#  75.64,
#  75.75,
#  75.78,
#  75.62,
#  75.62,
#  75.61,
#  75.6,
#  75.61,
#  75.36,
#  75.34,
#  75.43,
#  75.6,
#  75.44,
#  75.63,
#  75.15,
#  75.03,
#  75.03,
#  75.03,
#  74.97,
#  75.17,
#  75.16,
#  75.11,
#  75.54,
#  75.54,
#  74.97,
#  75.02,
#  75.58,
#  75.53,
#  75.15,
#  75.58,
#  75.06,
#  75.17,
#  396.44,
#  436.98,
#  396.27,
#  399.03,
#  87.61,
#  83.78,
#  87.6,
#  87.53,
#  87.72,
#  86.85,
#  84.89,
#  75.49,
#  75.15,
#  75.6,
#  75.58,
#  75.59,
#  75.57,
#  75.59,
#  75.58,
#  75.58,
#  75.49,
#  75.48,
#  75.56,
#  75.56,
#  75.56,
#  75.55,
#  75.55,
#  75.55,
#  75.54,
#  75.53,
#  75.54,
#  75.53,
#  75.53,
#  75.53,
#  75.53,
#  75.51,
#  75.5,
#  75.5,
#  75.55,
#  75.51,
#  75.55,
#  75.53,
#  75.15,
#  74.95,
#  75.14,
#  75.53,
#  75.26,
#  75.55,
#  74.84,
#  75.27,
#  75.51,
#  75.26,
#  75.09,
#  75.49,
#  74.5,
#  75.29,
#  75.4,
#  75.5,
#  75.49,
#  75.45,
#  75.49,
#  75.28,
#  75.26,
#  75.5,
#  75.22,
#  75.51,
#  75.29,
#  75.29,
#  75.31,
#  75.49,
#  75.41,
#  75.46,
#  75.27,
#  75.41,
#  75.35,
#  479.62,
#  75.21,
#  75.47,
#  75.4,
#  75.39,
#  75.4,
#  75.41,
#  75.51,
#  75.35,
#  75.48,
#  75.32,
#  75.37,
#  75.49,
#  75.36,
#  210.17,
#  567.49,
#  567.49,
#  566.48,
#  529.57,
#  75.38,
#  75.39,
#  75.5,
#  75.28,
#  75.57,
#  153.31,
#  458.54,
#  231.6,
#  571.54,
#  568.75,
#  569.26,
#  568.79,
#  569.26,
#  569.03,
#  569.03,
#  571.54,
#  569.03,
#  568.87,
#  363.08,
#  571.5,
#  373.31,
#  131.91,
#  85.5,
#  145.34,
#  300.74,
#  159.49,
#  160.05,
#  134.24,
#  369.86,
#  371.95,
#  87.08,
#  87.02,
#  86.12,
#  87.02,
#  114.4,
#  58.44,
#  355.47,
#  354.94,
#  37.73,
#  202.28,
#  514.57,
#  320.69,
#  348.59,
#  332.74,
#  104.27,
#  233.85,
#  290.13,
#  402.94,
#  113.62,
#  597.99,
#  331.15,
#  135.06,
#  317.96,
#  316.83,
#  86.02,
#  413.17,
#  52.59,
#  158.51,
#  167.25,
#  418.07,
#  87.39,
#  367.86,
#  367.78,
#  87.37,
#  87.25,
#  367.94,
#  76.38,
#  75.5,
#  74.0,
#  73.99,
#  73.63,
#  73.99,
#  74.0,
#  86.32,
#  213.79,
#  228.54,
#  549.0,
#  190.21,
#  527.9,
#  350.28,
#  467.68,
#  43.83,
#  468.58,
#  306.22,
#  340.2,
#  503.62,
#  171.9,
#  387.0,
#  424.35,
#  469.25,
#  382.59,
#  351.8,
#  215.57,
#  85.53,
#  85.59,
#  301.46,
#  74.86,
#  85.53,
#  74.74,
#  185.51,
#  85.91,
#  25.34,
#  116.32,
#  85.91,
#  253.16,
#  536.62,
#  535.83,
#  294.43,
#  292.51,
#  386.68,
#  293.38,
#  259.34,
#  383.88,
#  323.56,
#  159.31,
#  11.25,
#  325.58,
#  224.4,
#  452.91,
#  515.33,
#  313.03,
#  339.24,
#  476.49,
#  86.63,
#  86.63,
#  86.63,
#  86.22,
#  74.96,
#  236.05,
#  235.69,
#  189.09,
#  86.24,
#  86.11,
#  86.24,
#  86.62,
#  128.3,
#  316.97,
#  127.1,
#  86.23,
#  87.36,
#  86.87,
#  182.46,
#  176.33,
#  86.21,
#  74.94,
#  424.38,
#  503.69,
#  484.02,
#  487.16,
#  482.18,
#  84.82,
#  133.57,
#  479.06,
#  208.35,
#  248.81,
#  479.13,
#  332.85,
#  45.19,
#  360.37,
#  295.6,
#  35.42,
#  367.5,
#  36.35,
#  86.49,
#  85.67,
#  75.5,
#  210.29,
#  75.3,
#  75.6,
#  86.14,
#  277.09,
#  351.59,
#  273.67,
#  495.59,
#  351.52,
#  85.68,
#  74.86,
#  75.38,
#  75.4,
#  84.83,
#  85.66,
#  ...]

# %%
plt.plot(channel_picks)
#plt.ylim([7000,8000])
plt.ylabel('Time (s)')
plt.xlabel('Channel Number')
# Out:
# Text(0.5, 0, 'Channel Number')

# %%
local_earthquake_quicklook(dates,data_filt,st,st2,x_max,
                           stitle,das_vmax=0.02,
                           network_name=network_name)

# %% [markdown]
# # Routine for picking wave arrival times from lcoal events

# %%
#Function that returns the DAS data according to USGS earthquake events

def das_downloader(this_id, cab='seadasn'):
    this_event = event_df[event_df.id==this_id]
    t0 = this_event['time'].iloc[0]

    cable = cab
    record_length = 10 #minutes
    
    try:
        if cable == 'seadasn':
            prefix = 'seadasn'
            network_name = 'SeaDAS-N'
            if t0 < datetime.datetime(2022, 6, 20, 0, 0, 0):
                datastore='/data/data0/seadasn_2022-03-17_2022-06-20/'
            else:
                datastore='/data/data7/seadasn/'

        elif cable == 'whidbey':
            prefix = 'whidbey'
            network_name='Whidbey-DAS'
            datastore = '/data/data5/Converted/'

        data,dates,attrs = open_sintela_file(prefix,
                                             t0,
                                             datastore,
                                             number_of_files=record_length,
                                             verbose=True)
        x_max=data.shape[1] * attrs['SpatialSamplingInterval']
        
        low_cut = 2
        hi_cut = 10

        b,a = butter(2,(low_cut,hi_cut),'bp',fs=attrs['MaximumFrequency']*2)
        data_filt = filtfilt(b,a,data,axis=0)
    
    except:
        print('No data for thhis quake!')
        data = None
        dates = None
        attrs = None
        x_max = None
        data_filt = None
    return data, dates, attrs, x_max, this_id, data_filt

# %%
#Load events (specify search radius)
events = search(starttime = datetime.datetime(2022, 3, 17, 0, 0), 
                endtime   = datetime.datetime.now(),
                maxradiuskm=30, 
                latitude=47.60, 
                longitude=-122.33)

print("Returned %s events" % len(events))

#Get list of USGS events
event_df = get_summary_data_frame(events)
event_df = event_df.sort_values(by=['magnitude'],ascending=False)

#Create a list with the event id numbers for data download
earthquake_list = event_df['id'].values.tolist()
# Out:
# Returned 57 events

# %%
arrival_picks = {}

for i in earthquake_list:
    
    data, dates, attrs, x_max, this_id, data_filt = das_downloader(i)
    
    if  x_max != None:
        channel_picks = []
        chan_number = 0
        for channel in data_filt.T:
            das_trace = obspy.core.trace.Trace(channel)
            das_trace.stats['sampling_rate'] = 100.0
            df = das_trace.stats.sampling_rate
            cft = classic_sta_lta(das_trace, int(5 * df), int(10 * df))

            channel_picks.append( cft.argmax() / 100 )

            chan_number +=1
    
    arrival_picks[str(i)] = channel_picks
# Out:
# /data/data7/seadasn/seadasn_2022-06-25_13-08*.h5
# No data for thhis quake!
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-26_22-22*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-26_22-23*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-26_22-24*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-26_22-25*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-26_22-26*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-26_22-27*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-26_22-28*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-26_22-29*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-26_22-30*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-26_22-31*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-11_19-42*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-11_19-43*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-11_19-44*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-11_19-45*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-11_19-46*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-11_19-47*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-11_19-48*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-11_19-49*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-11_19-50*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-11_19-51*.h5
# /data/data7/seadasn/seadasn_2022-10-05_17-45*.h5
# No data for thhis quake!
# /data/data7/seadasn/seadasn_2022-09-27_22-04*.h5
# No data for thhis quake!
# /data/data7/seadasn/seadasn_2022-09-10_02-48*.h5
# No data for thhis quake!
# /data/data7/seadasn/seadasn_2022-10-19_20-25*.h5
# No data for thhis quake!
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-19_23-49*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-19_23-50*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-19_23-51*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-19_23-52*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-19_23-53*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-19_23-54*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-19_23-55*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-19_23-56*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-19_23-57*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-19_23-58*.h5
# /data/data7/seadasn/seadasn_2022-10-27_08-01*.h5
# No data for thhis quake!
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-30_00-03*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-30_00-04*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-30_00-05*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-30_00-06*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-30_00-07*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-30_00-08*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-30_00-09*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-30_00-10*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-30_00-11*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-30_00-12*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-19_13-56*.h5
# No data for thhis quake!
# /data/data7/seadasn/seadasn_2022-09-25_10-04*.h5
# No data for thhis quake!
# /data/data7/seadasn/seadasn_2022-09-27_22-08*.h5
# No data for thhis quake!
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_19-40*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_19-41*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_19-42*.h5
# File problem with: /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_19-42-00_UTC_006211.h5
# [Errno 2] Unable to open file (unable to open file: name = '/data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_19-42-00_UTC_006211.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_19-43*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_19-44*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_19-45*.h5
# File problem with: /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_19-45-00_UTC_007935.h5
# [Errno 2] Unable to open file (unable to open file: name = '/data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_19-45-00_UTC_007935.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_19-46*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_19-47*.h5
# File problem with: /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_19-47-00_UTC_006211.h5
# [Errno 2] Unable to open file (unable to open file: name = '/data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_19-47-00_UTC_006211.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_19-48*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_19-49*.h5
# /data/data7/seadasn/seadasn_2022-09-12_22-57*.h5
# No data for thhis quake!
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-19_03-48*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-19_03-49*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-19_03-50*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-19_03-51*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-19_03-52*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-19_03-53*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-19_03-54*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-19_03-55*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-19_03-56*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-19_03-57*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-03_02-28*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-03_02-29*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-03_02-30*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-03_02-31*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-03_02-32*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-03_02-33*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-03_02-34*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-03_02-35*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-03_02-36*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-03_02-37*.h5
# /data/data7/seadasn/seadasn_2022-10-12_00-53*.h5
# No data for thhis quake!
# /data/data7/seadasn/seadasn_2022-08-20_02-26*.h5
# No data for thhis quake!
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-10_15-00*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-10_15-01*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-10_15-02*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-10_15-03*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-10_15-04*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-10_15-05*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-10_15-06*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-10_15-07*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-10_15-08*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-10_15-09*.h5
# /data/data7/seadasn/seadasn_2022-08-30_01-35*.h5
# No data for thhis quake!
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-11_10-48*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-11_10-49*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-11_10-50*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-11_10-51*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-11_10-52*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-11_10-53*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-11_10-54*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-11_10-55*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-11_10-56*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-11_10-57*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-11_15-21*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-11_15-22*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-11_15-23*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-11_15-24*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-11_15-25*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-11_15-26*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-11_15-27*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-11_15-28*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-11_15-29*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-11_15-30*.h5
# /data/data7/seadasn/seadasn_2022-06-26_11-29*.h5
# No data for thhis quake!
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-04_20-14*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-04_20-15*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-04_20-16*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-04_20-17*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-04_20-18*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-04_20-19*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-04_20-20*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-04_20-21*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-04_20-22*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-04_20-23*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-30_01-13*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-30_01-14*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-30_01-15*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-30_01-16*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-30_01-17*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-30_01-18*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-30_01-19*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-30_01-20*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-30_01-21*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-30_01-22*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-29_23-29*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-29_23-30*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-29_23-31*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-29_23-32*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-29_23-33*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-29_23-34*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-29_23-35*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-29_23-36*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-29_23-37*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-29_23-38*.h5
# /data/data7/seadasn/seadasn_2022-10-12_18-51*.h5
# No data for thhis quake!
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-18_12-57*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-18_12-58*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-18_12-59*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-18_13-00*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-18_13-01*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-18_13-02*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-18_13-03*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-18_13-04*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-18_13-05*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-18_13-06*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-29_17-59*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-29_18-00*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-29_18-01*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-29_18-02*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-29_18-03*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-29_18-04*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-29_18-05*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-29_18-06*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-29_18-07*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-29_18-08*.h5
# /data/data7/seadasn/seadasn_2022-10-29_10-10*.h5
# No data for thhis quake!
# /data/data7/seadasn/seadasn_2022-07-15_13-25*.h5
# No data for thhis quake!
# /data/data7/seadasn/seadasn_2022-09-04_12-22*.h5
# No data for thhis quake!
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-12_09-35*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-12_09-36*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-12_09-37*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-12_09-38*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-12_09-39*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-12_09-40*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-12_09-41*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-12_09-42*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-12_09-43*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-06-12_09-44*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-12_22-29*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-12_22-30*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-12_22-31*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-12_22-32*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-12_22-33*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-12_22-34*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-12_22-35*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-12_22-36*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-12_22-37*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-12_22-38*.h5
# /data/data7/seadasn/seadasn_2022-06-25_13-28*.h5
# No data for thhis quake!
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-04_14-17*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-04_14-18*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-04_14-19*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-04_14-20*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-04_14-21*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-04_14-22*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-04_14-23*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-04_14-24*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-04_14-25*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-04_14-26*.h5
# /data/data7/seadasn/seadasn_2022-09-14_06-15*.h5
# No data for thhis quake!
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-03_04-37*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-03_04-38*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-03_04-39*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-03_04-40*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-03_04-41*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-03_04-42*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-03_04-43*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-03_04-44*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-03_04-45*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-03_04-46*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-22_13-24*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-22_13-25*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-22_13-26*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-22_13-27*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-22_13-28*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-22_13-29*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-22_13-30*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-22_13-31*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-22_13-32*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-22_13-33*.h5
# /data/data7/seadasn/seadasn_2022-10-14_03-52*.h5
# No data for thhis quake!
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-22_12-39*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-22_12-40*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-22_12-41*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-22_12-42*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-22_12-43*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-22_12-44*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-22_12-45*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-22_12-46*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-22_12-47*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-22_12-48*.h5
# /data/data7/seadasn/seadasn_2022-08-11_11-13*.h5
# No data for thhis quake!
# /data/data7/seadasn/seadasn_2022-06-26_17-47*.h5
# No data for thhis quake!
# /data/data7/seadasn/seadasn_2022-10-14_03-57*.h5
# No data for thhis quake!
# /data/data7/seadasn/seadasn_2022-07-25_18-07*.h5
# No data for thhis quake!
# /data/data7/seadasn/seadasn_2022-06-25_13-41*.h5
# No data for thhis quake!
# /data/data7/seadasn/seadasn_2022-06-25_13-11*.h5
# No data for thhis quake!
# /data/data7/seadasn/seadasn_2022-09-14_03-10*.h5
# No data for thhis quake!
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-20_06-04*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-20_06-05*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-20_06-06*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-20_06-07*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-20_06-08*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-20_06-09*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-20_06-10*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-20_06-11*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-20_06-12*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-04-20_06-13*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-18_05-13*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-18_05-14*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-18_05-15*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-18_05-16*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-18_05-17*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-18_05-18*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-18_05-19*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-18_05-20*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-18_05-21*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-05-18_05-22*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-29_16-16*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-29_16-17*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-29_16-18*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-29_16-19*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-29_16-20*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-29_16-21*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-29_16-22*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-29_16-23*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-29_16-24*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-29_16-25*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-18_07-17*.h5
# No data for thhis quake!
# /data/data7/seadasn/seadasn_2022-06-25_13-10*.h5
# No data for thhis quake!
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-27_10-09*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-27_10-10*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-27_10-11*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-27_10-12*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-27_10-13*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-27_10-14*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-27_10-15*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-27_10-16*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-27_10-17*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-27_10-18*.h5
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_17-28*.h5
# File problem with: /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_17-28-00_UTC_007934.h5
# [Errno 2] Unable to open file (unable to open file: name = '/data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_17-28-00_UTC_007934.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_17-29*.h5
# File problem with: /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_17-29-00_UTC_002025.h5
# all the input arrays must have same number of dimensions, but the array at index 0 has 1 dimension(s) and the array at index 1 has 2 dimension(s)
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_17-30*.h5
# File problem with: /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_17-30-00_UTC_002025.h5
# [Errno 2] Unable to open file (unable to open file: name = '/data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_17-30-00_UTC_002025.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_17-31*.h5
# File problem with: /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_17-31-00_UTC_006210.h5
# [Errno 2] Unable to open file (unable to open file: name = '/data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_17-31-00_UTC_006210.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_17-32*.h5
# File problem with: /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_17-32-00_UTC_002027.h5
# all the input arrays must have same number of dimensions, but the array at index 0 has 1 dimension(s) and the array at index 1 has 2 dimension(s)
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_17-33*.h5
# File problem with: /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_17-33-00_UTC_007934.h5
# [Errno 2] Unable to open file (unable to open file: name = '/data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_17-33-00_UTC_007934.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_17-34*.h5
# File problem with: /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_17-34-00_UTC_002029.h5
# all the input arrays must have same number of dimensions, but the array at index 0 has 1 dimension(s) and the array at index 1 has 2 dimension(s)
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_17-35*.h5
# File problem with: /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_17-35-00_UTC_002030.h5
# all the input arrays must have same number of dimensions, but the array at index 0 has 1 dimension(s) and the array at index 1 has 2 dimension(s)
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_17-36*.h5
# File problem with: /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_17-36-00_UTC_002031.h5
# all the input arrays must have same number of dimensions, but the array at index 0 has 1 dimension(s) and the array at index 1 has 2 dimension(s)
# /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_17-37*.h5
# File problem with: /data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_17-37-00_UTC_006210.h5
# [Errno 2] Unable to open file (unable to open file: name = '/data/data0/seadasn_2022-03-17_2022-06-20/seadasn_2022-03-28_17-37-00_UTC_006210.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# No data for thhis quake!
# /data/data7/seadasn/seadasn_2022-06-26_14-58*.h5
# No data for thhis quake!

# %%
arrival_times_1749 = []

for i in arrival_picks:
    if len(arrival_picks[i]) == 1749:
        print(i)
        arrival_times_1749.append(arrival_picks[i])
# Out:
# uw61846087
# uw61850536
# uw61877107
# uw61884286
# uw61879156
# uw61888846
# uw61842061
# uw61890241
# uw61837027
# uw61824027
# uw61874622
# uw61884291
# uw61844597
# uw61847381
# uw61878407
# uw61864627
# uw61841392
# uw61876201
# uw61830387
# uw61828042
# uw61835371
# uw61837007
# uw61878547
# uw61841216
# uw61835231
# uw61881517
# uw61862181
# uw61868782
# uw61850701
# uw61827977
# uw61880126
# uw61836281
# uw61841186

# %%
arrival_times_1749 = np.asarray(arrival_times_1749)

# %%
plt.imshow(arrival_times_1749, aspect='auto')
plt.colorbar(label = 'Arrival Time (s)')

# %%
#Load the fiber location and calibration data
fiber_location = pd.read_csv('fiberroute.csv', header=1)
fiber_calibration = pd.read_csv('calibration.csv', header=1)

#Plot
fig, ax = plt.subplots(figsize = (8,7))
ax.plot(fiber_location['Long'], fiber_location['Lat'], zorder=1, alpha= 0.2, c='b')
ax.plot(fiber_calibration['Long'], fiber_calibration['Lat'], zorder=1, alpha= 0.2, c='g')
# Out:
#          Lat        Long  Elev  Opt Dist  Scale Name  Scale Number  \
# 0  47.654085 -122.309411   0.0       1.0         NaN           NaN
# 1  47.661686 -122.312116   0.0    1500.0         NaN           NaN
# 2  47.691258 -122.317682   0.0    6400.0         NaN           NaN
# 3  47.757981 -122.191467   0.0   29043.0         NaN           NaN
#
#    Description  State  Purpose  Scale Suffix
# 0          NaN    NaN      NaN           NaN
# 1          NaN    NaN      NaN           NaN
# 2          NaN    NaN      NaN           NaN
# 3          NaN    NaN      NaN           NaN

# %%
# Out:
# Text(0.5, 1.0, 'Plotting Spatial Data on Riyadh Map')

# %%
#Calculate the fiber distance between points in the fiber location file
import geopy.distance
fiber_distance = []

for index, row in fiber_location.iterrows():
    if index == 0 :
        fiber_distance.append(0)
        print(index, 'index = 0')
    elif index <= len(fiber_location.index) -1:
        coords_1 = (row['Lat'], row['Long'])
        coords_2 = (fiber_location.iloc[index-1]['Lat'], fiber_location.iloc[index-1]['Long'])
        distance = geopy.distance.geodesic(coords_1, coords_2).m
        fiber_distance.append(distance)
        print('index = ', index)
        
fiber_location['Fiber Dist'] = fiber_distance
# Out:
# 0 index = 0
# index =  1
# index =  2
# index =  3
# index =  4
# index =  5
# index =  6
# index =  7
# index =  8
# index =  9
# index =  10
# index =  11
# index =  12
# index =  13
# index =  14
# index =  15
# index =  16
# index =  17
# index =  18
# index =  19
# index =  20
# index =  21
# index =  22
# index =  23
# index =  24
# index =  25
# index =  26
# index =  27
# index =  28
# index =  29
# index =  30
# index =  31
# index =  32
# index =  33
# index =  34
# index =  35
# index =  36
# index =  37
# index =  38
# index =  39
# index =  40
# index =  41
# index =  42
# index =  43
# index =  44
# index =  45
# index =  46
# index =  47
# index =  48
# index =  49
# index =  50
# index =  51
# index =  52
# index =  53
# index =  54
# index =  55
# index =  56
# index =  57
# index =  58
# index =  59
# index =  60
# index =  61
# index =  62
# index =  63
# index =  64
# index =  65
# index =  66
# index =  67
# index =  68
# index =  69
# index =  70
# index =  71
# index =  72
# index =  73
# index =  74
# index =  75
# index =  76
# index =  77
# index =  78
# index =  79
# index =  80
# index =  81
# index =  82
# index =  83
# index =  84
# index =  85
# index =  86
# index =  87
# index =  88
# index =  89
# index =  90
# index =  91
# index =  92
# index =  93
# index =  94
# index =  95
# index =  96
# index =  97
# index =  98
# index =  99
# index =  100
# index =  101
# index =  102
# index =  103
# index =  104
# index =  105
# index =  106
# index =  107
# index =  108
# index =  109
# index =  110
# index =  111
# index =  112
# index =  113
# index =  114
# index =  115
# index =  116
# index =  117
# index =  118
# index =  119
# index =  120
# index =  121
# index =  122
# index =  123
# index =  124
# index =  125
# index =  126
# index =  127
# index =  128
# index =  129
# index =  130
# index =  131
# index =  132
# index =  133
# index =  134
# index =  135
# index =  136
# index =  137
# index =  138
# index =  139
# index =  140
# index =  141
# index =  142
# index =  143
# index =  144
# index =  145
# index =  146
# index =  147
# index =  148
# index =  149
# index =  150
# index =  151
# index =  152
# index =  153
# index =  154
# index =  155
# index =  156
# index =  157
# index =  158
# index =  159
# index =  160
# index =  161
# index =  162
# index =  163
# index =  164
# index =  165
# index =  166
# index =  167
# index =  168
# index =  169
# index =  170
# index =  171
# index =  172
# index =  173
# index =  174
# index =  175
# index =  176
# index =  177
# index =  178
# index =  179
# index =  180
# index =  181
# index =  182
# index =  183
# index =  184
# index =  185
# index =  186
# index =  187
# index =  188
# index =  189
# index =  190
# index =  191
# index =  192
# index =  193
# index =  194
# index =  195
# index =  196
# index =  197
# index =  198
# index =  199
# index =  200
# index =  201
# index =  202
# index =  203
# index =  204
# index =  205
# index =  206
# index =  207
# index =  208
# index =  209
# index =  210

# %%
fiber_location
# Out:
#            Lat        Long  Elev  Description  Fiber Dist
# 0    47.654085 -122.309411     0          NaN    0.000000
# 1    47.661686 -122.312116     0          NaN  869.191066
# 2    47.661686 -122.312127     0          NaN    0.826231
# 3    47.661742 -122.312127     0          NaN    6.226289
# 4    47.661742 -122.312036     0          NaN    6.835180
# ..         ...         ...   ...          ...         ...
# 206  47.758301 -122.194216     0          NaN  153.953659
# 207  47.758385 -122.193560     0          NaN   50.061343
# 208  47.758206 -122.191504     0          NaN  155.424543
# 209  47.757981 -122.191496     0          NaN   25.023952
# 210  47.757981 -122.191467     0          NaN    2.174238
#
# [211 rows x 5 columns]

# %%
fiber_calibration
# Out:
#          Lat        Long  Elev  Opt Dist  Scale Name  Scale Number  \
# 0  47.654085 -122.309411   0.0       1.0         NaN           NaN
# 1  47.661686 -122.312116   0.0    1500.0         NaN           NaN
# 2  47.691258 -122.317682   0.0    6400.0         NaN           NaN
# 3  47.757981 -122.191467   0.0   29043.0         NaN           NaN
#
#    Description  State  Purpose  Scale Suffix
# 0          NaN    NaN      NaN           NaN
# 1          NaN    NaN      NaN           NaN
# 2          NaN    NaN      NaN           NaN
# 3          NaN    NaN      NaN           NaN

# %%
cumm = fiber_location['Fiber Dist'].sum()

# %%
cumm
# Out:
# 24474.306756313275
