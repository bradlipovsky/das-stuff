# %% [markdown]
# # Global-Earthquake seismology with DAS
#
# #### Todo List:
# 1. Reference earthquakes by Evid rather than dataframe index
# 2. Make a map of all of the detected events
# 3. Try some xcorr

# %%
import h5py
import matplotlib.pyplot as plt
from scipy.signal import butter, filtfilt
import numpy as np
import datetime
import pandas as pd
from dasquakes import *
import obspy
from obspy import UTCDateTime
from obspy.clients.fdsn import Client
from libcomcat.search import search
from libcomcat.dataframes import get_summary_data_frame
#import sys
#!{sys.executable} -m pip install geopy
import geopy.distance
from obspy.taup import TauPyModel
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /home/velgueta/.conda/envs/python-obspy/share/proj failed

# %% [markdown]
# ### Get a list of events from USGS

# %%
events = search(starttime = datetime.datetime(2022, 3, 17, 0, 0), 
                endtime   = datetime.datetime(2023,1,9,0,0),
                minmagnitude=7.0)
event_df = get_summary_data_frame(events)
print("Returned %s events" % len(events))
# Out:
# Returned 11 events

# %%
event_df = event_df.sort_values(by=['time'],ascending=False)
event_df
# Out:
#             id                    time                               location  \
# 10  us7000j2yw 2023-01-08 12:32:42.372                                Vanuatu
# 9   us7000irfb 2022-11-22 02:03:06.891   18 km SW of Malango, Solomon Islands
# 8   us7000ip8h 2022-11-12 07:09:13.514                                   None
# 7   us7000ip0l 2022-11-11 10:48:46.710            205 km ESE of Neiafu, Tonga
# 6   us7000ingi 2022-11-09 09:51:04.068              south of the Fiji Islands
# 5   us7000i9bw 2022-09-19 18:05:08.217         35 km SSW of Aguililla, Mexico
# 4   us7000i7ya 2022-09-14 11:04:06.558         209 km SSE of Isangel, Vanuatu
# 3   us6000iitd 2022-09-10 23:47:00.233  70 km E of Kainantu, Papua New Guinea
# 2   us6000i5rd 2022-07-27 00:43:26.871        11 km NE of Bantay, Philippines
# 1   us7000hcmn 2022-05-26 12:02:21.110              10 km W of Azángaro, Peru
# 0   us7000gymk 2022-03-31 05:44:01.146       southeast of the Loyalty Islands
#
#     latitude  longitude    depth  magnitude   alert  \
# 10  -14.9466   166.8794   29.000        7.0   green
# 9    -9.8198   159.6033   14.000        7.0   green
# 8   -20.1112  -178.3453  579.000        7.0   green
# 7   -19.2881  -172.1471   37.000        7.3   green
# 6   -26.0901   178.3427  660.000        7.0   green
# 5    18.4552  -102.9561   26.943        7.6  yellow
# 4   -21.1909   170.2666  137.000        7.0   green
# 3    -6.2944   146.5038  116.000        7.6  yellow
# 2    17.5207   120.8181   33.729        7.0  yellow
# 1   -14.9076   -70.2924  236.000        7.2   green
# 0   -22.5860   170.3744   10.000        7.0   green
#
#                                                   url   eventtype  \
# 10  https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 9   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 8   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 7   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 6   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 5   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 4   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 3   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 2   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 1   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
# 0   https://earthquake.usgs.gov/earthquakes/eventp...  earthquake
#
#     significance
# 10           768
# 9            768
# 8            755
# 7            833
# 6            755
# 5           1799
# 4            761
# 3            965
# 2           1351
# 1            876
# 0            763

# %% [markdown]
# ### Choose an event to analyze

# %%
#this_event = event_df[event_df.id=='us6000iitd']
#t0 = this_event['time'].iloc[0]

#this_event

# %%
for index,this_event in event_df.iterrows():
    
    this_id = this_event['id']
    
    this_event_new = event_df[event_df.id==this_id]
    
    coords_1 = (this_event_new.latitude.to_numpy()[0], this_event_new.longitude.to_numpy()[0])
    coords_2 = (47.6062, 122.3321)
    dist_km = geopy.distance.geodesic(coords_1, coords_2).km
    dist_deg = dist_km / 40075 * 360

    model = TauPyModel(model="iasp91")
    arrivals = model.get_travel_times(source_depth_in_km=this_event_new.depth.to_numpy()[0],
                                  distance_in_degree=dist_deg)
    print(f'Distance = {dist_deg} deg\nArrival time = {arrivals[0].time} s after source time.')
    t0 = this_event_new['time'].iloc[0]
    t0 = t0 + datetime.timedelta(seconds=arrivals[0].time) # Correct for travel time
    t0 = t0 - datetime.timedelta(minutes=5) # Get one minute of data before the first arrival
    print(this_event['id'])
    
    stitle=f"M {this_event_new['magnitude'].to_numpy()[0]}, "\
           f"{this_event_new['location'].to_numpy()[0]}, "\
           f"{str(this_event_new['time'].to_numpy()[0])[0:-10]} UTC"
    #cable = 'seadasn'
    cable = 'whidbey'
    record_length = 25 #minutes

    prefix, network_name, datastore = data_wrangler(cable,record_length,t0)
    try:
        data,dates,attrs = open_sintela_file(prefix,
                                     t0,
                                     datastore,
                                     number_of_files=record_length,
                                     verbose=True)
        x_max=data.shape[1] * attrs['SpatialSamplingInterval']
        low_cut = 0.01
        hi_cut = 1

        b,a = butter(2,(low_cut,hi_cut),'bp',fs=attrs['MaximumFrequency']*2)
        data_filt = filtfilt(b,a,data,axis=0)
    
        client = Client("IRIS")

        t1 = UTCDateTime( t0.strftime("%Y-%m-%dT%H:%M:%S") )
        dt = datetime.timedelta(minutes=record_length)
        t2 = UTCDateTime( (t0+dt).strftime("%Y-%m-%dT%H:%M:%S") )

        st = client.get_waveforms("UW", "NOWS", "--", "HNN", t1, t2, attach_response=True)
        # st.decimate(5, strict_length=False, no_filter=False) #everything should be at 40Hz now
        st2 = client.get_waveforms("IU", "COR", "00", "HH1", t1, t2, attach_response=True)

        pre_filt = (low_cut/2, low_cut, hi_cut, hi_cut*2)
        st.remove_response(output='VEL', pre_filt=pre_filt)
        st2.remove_response(output='VEL', pre_filt=pre_filt)
    
        filename = f"globalearthquakestest/"+this_id
        local_earthquake_quicklook(dates,data_filt,st,st2,x_max,
                           stitle,filename=filename,das_vmax=5,
                           network_name=network_name,
                           skip_seismograms=False)
    except ValueError:
        continue
# Out:
# Distance = 73.85162493923836 deg
# Arrival time = 691.9721560375248 s after source time.
# us7000j2yw
# Searching for files matching: /data/data6/whidbey/whidbey_2023-01-08_12-39*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2023-01-08_12-40*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2023-01-08_12-41*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2023-01-08_12-42*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2023-01-08_12-43*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2023-01-08_12-44*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2023-01-08_12-45*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2023-01-08_12-46*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2023-01-08_12-47*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2023-01-08_12-48*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2023-01-08_12-49*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2023-01-08_12-50*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2023-01-08_12-51*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2023-01-08_12-52*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2023-01-08_12-53*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2023-01-08_12-54*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2023-01-08_12-55*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2023-01-08_12-56*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2023-01-08_12-57*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2023-01-08_12-58*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2023-01-08_12-59*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2023-01-08_13-00*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2023-01-08_13-01*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2023-01-08_13-02*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2023-01-08_13-03*h5
# Distance = 66.0105736250373 deg
# Arrival time = 646.02870542489 s after source time.
# us7000irfb
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-22_02-08*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-22_02-09*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-22_02-10*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-22_02-11*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-22_02-12*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-22_02-13*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-22_02-14*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-22_02-15*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-22_02-16*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-22_02-17*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-22_02-18*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-22_02-19*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-22_02-20*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-22_02-21*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-22_02-22*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-22_02-23*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-22_02-24*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-22_02-25*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-22_02-26*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-22_02-27*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-22_02-28*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-22_02-29*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-22_02-30*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-22_02-31*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-22_02-32*h5
# Distance = 85.77822263174653 deg
# Arrival time = 698.6965559875367 s after source time.
# us7000ip8h
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-12_07-15*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-12_07-16*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-12_07-17*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-12_07-18*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-12_07-19*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-12_07-20*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-12_07-21*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-12_07-22*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-12_07-23*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-12_07-24*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-12_07-25*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-12_07-26*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-12_07-27*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-12_07-28*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-12_07-29*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-12_07-30*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-12_07-31*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-12_07-32*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-12_07-33*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-12_07-34*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-12_07-35*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-12_07-36*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-12_07-37*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-12_07-38*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-12_07-39*h5
# Distance = 88.62598467404293 deg
# Arrival time = 769.1251649447007 s after source time.
# us7000ip0l
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-11_10-56*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-11_10-57*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-11_10-58*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-11_10-59*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-11_11-00*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-11_11-01*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-11_11-02*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-11_11-03*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-11_11-04*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-11_11-05*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-11_11-06*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-11_11-07*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-11_11-08*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-11_11-09*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-11_11-10*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-11_11-11*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-11_11-12*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-11_11-13*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-11_11-14*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-11_11-15*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-11_11-16*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-11_11-17*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-11_11-18*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-11_11-19*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-11_11-20*h5
# Distance = 88.9125359804457 deg
# Arrival time = 706.2049590462607 s after source time.
# us7000ingi
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-09_09-57*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-09_09-58*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-09_09-59*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-09_10-00*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-09_10-01*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-09_10-02*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-09_10-03*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-09_10-04*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-09_10-05*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-09_10-06*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-09_10-07*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-09_10-08*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-09_10-09*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-09_10-10*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-09_10-11*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-09_10-12*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-09_10-13*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-09_10-14*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-09_10-15*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-09_10-16*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-09_10-17*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-09_10-18*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-09_10-19*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-09_10-20*h5
# Searching for files matching: /data/data6/whidbey/whidbey_2022-11-09_10-21*h5
# Distance = 102.52809826858976 deg
# Arrival time = 833.5828658134757 s after source time.
# us7000i9bw
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-19_18-14*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-19_18-15*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-19_18-16*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-19_18-17*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-19_18-18*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-19_18-19*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-19_18-20*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-19_18-21*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-19_18-22*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-19_18-23*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-19_18-24*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-19_18-25*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-19_18-26*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-19_18-27*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-19_18-28*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-19_18-29*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-19_18-30*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-19_18-31*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-19_18-32*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-19_18-33*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-19_18-34*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-19_18-35*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-19_18-36*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-19_18-37*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-19_18-38*h5
# Distance = 80.8376625536064 deg
# Arrival time = 718.5376636979895 s after source time.
# us7000i7ya
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-14_11-11*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-14_11-12*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-14_11-13*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-14_11-14*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-14_11-15*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-14_11-16*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-14_11-17*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-14_11-18*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-14_11-19*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-14_11-20*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-14_11-21*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-14_11-22*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-14_11-23*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-14_11-24*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-14_11-25*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-14_11-26*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-14_11-27*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-14_11-28*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-14_11-29*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-14_11-30*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-14_11-31*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-14_11-32*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-14_11-33*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-14_11-34*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-14_11-35*h5
# Distance = 57.7231350458985 deg
# Arrival time = 578.4878767271674 s after source time.
# us6000iitd
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-10_23-51*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-10_23-52*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-10_23-53*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-10_23-54*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-10_23-55*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-10_23-56*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-10_23-57*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-10_23-58*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-10_23-59*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-11_00-00*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-11_00-01*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-11_00-02*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-11_00-03*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-11_00-04*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-11_00-05*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-11_00-06*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-11_00-07*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-11_00-08*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-11_00-09*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-11_00-10*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-11_00-11*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-11_00-12*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-11_00-13*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-11_00-14*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-09-11_00-15*h5
# Distance = 29.999961174482806 deg
# Arrival time = 365.40002016680864 s after source time.
# us6000i5rd
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-27_00-44*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-27_00-45*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-27_00-46*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-27_00-47*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-27_00-48*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-27_00-49*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-27_00-50*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-27_00-51*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-27_00-52*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-27_00-53*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-27_00-54*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-27_00-55*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-27_00-56*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-27_00-57*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-27_00-58*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-27_00-59*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-27_01-00*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-27_01-01*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-27_01-02*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-27_01-03*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-27_01-04*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-27_01-05*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-27_01-06*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-27_01-07*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-07-27_01-08*h5
# Distance = 145.50238016439505 deg
# Arrival time = 999.857127339767 s after source time.
# us7000hcmn
# Searching for files matching: /data/data5/Converted/whidbey_2022-05-26_12-14*h5
# Distance = 82.08363494103821 deg
# Arrival time = 740.642665076493 s after source time.
# us7000gymk
# Searching for files matching: /data/data5/Converted/whidbey_2022-03-31_05-51*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-03-31_05-52*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-03-31_05-53*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-03-31_05-54*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-03-31_05-55*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-03-31_05-56*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-03-31_05-57*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-03-31_05-58*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-03-31_05-59*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-03-31_06-00*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-03-31_06-01*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-03-31_06-02*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-03-31_06-03*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-03-31_06-04*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-03-31_06-05*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-03-31_06-06*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-03-31_06-07*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-03-31_06-08*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-03-31_06-09*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-03-31_06-10*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-03-31_06-11*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-03-31_06-12*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-03-31_06-13*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-03-31_06-14*h5
# Searching for files matching: /data/data5/Converted/whidbey_2022-03-31_06-15*h5

# %% [markdown]
# ### Calculate arrival times

# %% [markdown]
# ### Load the DAS Data

# %% [markdown]
# Catalog

# %%
tf=['True','True','True','True','True','True','True','True','True','True','True','True']
tfn=np.array(tf).T
dataf = np.array([this_event.id, this_event.location, this_event.magnitude,tf]).T

df3 = pd.DataFrame(dataf,columns=['Id', 'Distance', 'Magnitude','Detected by Das'])
df3
